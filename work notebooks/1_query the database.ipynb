# %% [markdown]
# Importing libraries and setting up connection

# %%
import pymongo
from pymongo import MongoClient

# %%
# !pip install geopy

# %%
import pandas as pd
from pandas import DataFrame

# %%
import operator
from dotenv import load_dotenv
import os
import requests
import json
from functools import reduce
from geopy.distance import geodesic

# %%
#!pip install folium
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster

# %%
# Server connection
client = MongoClient("localhost:27017")

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
# Show names of existing databases
client.list_database_names()
# Out:
# ['Ironhack', 'admin', 'config', 'ironhacktest', 'local']

# %%
# Connection to the database
db = client.get_database("Ironhack")

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Ironhack')

# %%
db.list_collection_names()
# Out:
# ['companies']

# %%
collection = db.get_collection("companies")

# %% [markdown]
# ### Goal: Place the new company offices in the best place

# %% [markdown]
# #### Company details
#
# - Sector - GAMING industry
# - Employees - (85-90)
#
# #### Requirements
#
# - Nearby to other companies in the sector.
# - Near successful tech startups that have raised at least 1 Million dollars.
# - Near to Starbucks.
# - At least one airport in the city.
# - Near  se to vegan restaurants.
# - Entertainment sites around.
# - Daycare centers

# %% [markdown]
# ### Location

# %% [markdown]
# ### 1. Exploring the MongoDB dataset to select location

# %% [markdown]
# #### Obtain all companies that have less than 100 employees and that have an Appraisal Amount greater than 1,000,000.

# %%
filtered = {'ipo': {'$exists': True },
          'ipo.valuation_amount': {'$exists': True, '$gte': 1000000},
          'number_of_employees': { '$gt': 90 },
          'offices.city':{"$ne": "",}}  
project = {'_id': 0,'name': 1, 'ipo.valuation_amount': 1, 'offices.city': 1, 'number_of_employees': 1 }
result = collection.find(filtered, project)

pd.DataFrame.from_records(result)
# Out:
#                     name  number_of_employees  \
# 0               Facebook                 5299
# 1                Twitter                 1300
# 2                   Yelp                  800
# 3               LinkedIn                 4800
# 4             Brightcove                  220
# 5            KIT digital                  200
# 6              OpenTable                  550
# 7         ChannelAdvisor                  300
# 8                 Zillow                  600
# 9                    Wix                  400
# 10            Shutterfly                  611
# 11            Salesforce                 3500
# 12            QuinStreet                  500
# 13            Higher One                  380
# 14              Infoblox                  500
# 15               Marketo                  260
# 16                 Baidu                 6000
# 17               Geeknet                  127
# 18               Telenav                 1000
# 19        Rally Software                  430
# 20                  Mixi                  257
# 21              QlikTech                  600
# 22               Groupon                10000
# 23            SolarWinds                  354
# 24                  GREE                  700
# 25             DemandTec                  350
# 26  Cornerstone OnDemand                  881
# 27      Millennial Media                  137
#
#                                               offices  \
# 0   [{'city': 'Menlo Park'}, {'city': 'Dublin'}, {...
# 1                         [{'city': 'San Francisco'}]
# 2                         [{'city': 'San Francisco'}]
# 3                         [{'city': 'Mountain View'}]
# 4   [{'city': 'Cambridge'}, {'city': 'Tokyo'}, {'c...
# 5   [{'city': 'New York'}, {'city': 'Prague'}, {'c...
# 6                         [{'city': 'San Francisco'}]
# 7                           [{'city': 'Morrisville'}]
# 8                               [{'city': 'Seattle'}]
# 9   [{'city': 'Tel Aviv'}, {'city': 'San Francisco'}]
# 10                         [{'city': 'Redwood City'}]
# 11                        [{'city': 'San Francisco'}]
# 12                          [{'city': 'Foster City'}]
# 13                            [{'city': 'New Haven'}]
# 14                          [{'city': 'Santa Clara'}]
# 15                            [{'city': 'San Mateo'}]
# 16                              [{'city': 'Beijing'}]
# 17  [{'city': 'Fairfax'}, {'city': 'San Francisco'...
# 18  [{'city': 'Sunnyvale'}, {'city': 'Kirkland'}, ...
# 19  [{'city': 'Boulder'}, {'city': 'Denver'}, {'ci...
# 20                                [{'city': 'Tokyo'}]
# 21             [{'city': 'Radnor'}, {'city': 'Lund'}]
# 22  [{'city': 'Chicago'}, {'city': 'Palo Alto'}, {...
# 23                               [{'city': 'Austin'}]
# 24                                [{'city': 'Tokyo'}]
# 25       [{'city': 'San Carlos'}, {'city': 'London'}]
# 26                         [{'city': 'Santa Monica'}]
# 27                            [{'city': 'Baltimore'}]
#
#                                    ipo
# 0   {'valuation_amount': 104000000000}
# 1    {'valuation_amount': 18100000000}
# 2     {'valuation_amount': 1300000000}
# 3     {'valuation_amount': 9310000000}
# 4      {'valuation_amount': 290000000}
# 5      {'valuation_amount': 235000000}
# 6     {'valuation_amount': 1050000000}
# 7      {'valuation_amount': 287000000}
# 8     {'valuation_amount': 2550000000}
# 9      {'valuation_amount': 750000000}
# 10     {'valuation_amount': 350000000}
# 11     {'valuation_amount': 110000000}
# 12     {'valuation_amount': 140000000}
# 13    {'valuation_amount': 1060000000}
# 14     {'valuation_amount': 824000000}
# 15     {'valuation_amount': 465000000}
# 16    {'valuation_amount': 4000000000}
# 17     {'valuation_amount': 134000000}
# 18     {'valuation_amount': 337000000}
# 19     {'valuation_amount': 315000000}
# 20     {'valuation_amount': 970000000}
# 21    {'valuation_amount': 1000000000}
# 22   {'valuation_amount': 12800000000}
# 23     {'valuation_amount': 803000000}
# 24  {'valuation_amount': 108960000000}
# 25     {'valuation_amount': 245000000}
# 26     {'valuation_amount': 900000000}
# 27     {'valuation_amount': 973500000}

# %% [markdown]
# ### In the data frame it is observed that San Francisco is the most repeated location

# %% [markdown]
# #### Get all companies located in San Francisco that have at least 90 employees but fewer than 200. Excluding companies that have a value of None in the Offices / Latitude field.

# %%
filtered = {'offices.city': {'$eq': 'San Francisco'}, 
         'number_of_employees': { '$gt': 90,'$lt': 200 }, 
         'offices.latitude' : { '$ne': None }}
project = {"_id":0,"name":1,"offices.city": 1,"offices.latitude":1,"offices.longitude":1}
results = collection.find(filtered, project)

pd.DataFrame.from_records(results)
# Out:
#                        name                                            offices
# 0              PowerReviews  [{'city': 'San Francisco', 'latitude': 37.7795...
# 1                       hi5  [{'city': 'San Francisco', 'latitude': 37.7886...
# 2                    Tagged  [{'city': 'San Francisco', 'latitude': 37.7753...
# 3                     Blurb  [{'city': 'San Francisco', 'latitude': 37.7929...
# 4   The Climate Corporation  [{'city': 'San Francisco', 'latitude': 37.7828...
# 5                 99designs  [{'city': 'San Francisco', 'latitude': 37.7955...
# 6                  LiveRail  [{'city': 'San Francisco', 'latitude': 37.7871...
# 7      Wikimedia Foundation  [{'city': 'San Francisco', 'latitude': 37.7678...
# 8               SquareTrade  [{'city': 'San Francisco', 'latitude': 37.7895...
# 9                 ServePath  [{'city': 'San Francisco', 'latitude': 37.7898...
# 10                   GitHub  [{'city': 'San Francisco', 'latitude': 37.7751...
# 11                  Tealeaf  [{'city': 'San Francisco', 'latitude': 37.7912...
# 12                     iWin  [{'city': 'San Francisco', 'latitude': 37.7816...
# 13                Cloudmark  [{'city': 'San Francisco', 'latitude': 37.7795...
# 14                   TRUSTe  [{'city': 'San Francisco', 'latitude': 37.7886...
# 15               InsideView  [{'city': 'San Francisco', 'latitude': 37.7641...
# 16                   GoGrid  [{'city': 'San Francisco', 'latitude': 37.7895...
# 17                   Minted  [{'city': 'San Francisco', 'latitude': 37.7974...
# 18                   ngmoco  [{'city': 'San Francisco', 'latitude': 37.7705...
# 19                     Lyft  [{'city': 'San Francisco', 'latitude': 37.7899...
# 20                     Lyft  [{'city': 'San Francisco', 'latitude': 37.7899...
# 21                   Twilio  [{'city': 'San Francisco', 'latitude': 37.7898...
# 22              Clarabridge  [{'city': 'Reston', 'latitude': 38.946532, 'lo...
# 23    Workbridge Associates  [{'city': 'Arlington', 'latitude': 38.883297, ...
# 24                   Bomgar  [{'city': 'Ridgeland', 'latitude': 32.416174, ...
# 25                    Birst  [{'city': 'San Francisco', 'latitude': 37.7894...
# 26         Canopy Financial  [{'city': 'San Francisco', 'latitude': 37.7913...
# 27          ContinuumGlobal  [{'city': 'San Francisco', 'latitude': 37.7824...
# 28                   Sunrun  [{'city': 'San Francisco', 'latitude': 37.7871...
# 29              ZoomSystems  [{'city': 'San Francisco', 'latitude': 37.7816...

# %% [markdown]
# ### We choose 'hi5' as the first option

# %%
filtered = {'name' : 'hi5' }
project = {"_id":0,"offices.city": 1,"offices.latitude":1,"offices.longitude":1}
results = collection.find(filtered, project)

print(list(results))
# Out:
# [{'offices': [{'city': 'San Francisco', 'latitude': 37.788668, 'longitude': -122.400558}]}]

# %% [markdown]
# #### Get location

# %%
latitude = 37.788668
longitude = -122.400558

# %%
# Insert into a dataframe
location = [{'name': 'MyCompany', 'lat': latitude, 'lng': longitude, 'tag': 'my_location'}]
df_my_company = pd.DataFrame(location)
print(df_my_company)
# Out:
#         name        lat         lng          tag
# 0  MyCompany  37.788668 -122.400558  my_location

# %% [markdown]
# #### Visualization on  map

# %%
#prefix = fa lo ponemos cuando usemos los iconos de fontawesome.

map_1 = folium.Map(location = [latitude, longitude], zoom_start = 15)
office_loc = folium.Marker(location = [latitude, longitude], tooltip = "My Location")
icono = Icon(color = "orange",
             prefix = "fa",
             icon = "building-o",
             icon_color = "black",
             tooltip = "My Location")

# %%
location = [latitude, longitude]
marker_office = Marker(location = location, icon = icono)
marker_office.add_to(map_1)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1da5e570ba494ac9b2406adf5f5e2948%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1da5e570ba494ac9b2406adf5f5e2948%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1da5e570ba494ac9b2406adf5f5e2948%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1da5e570ba494ac9b2406adf5f5e2948%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.788668%2C%20-122.400558%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Exportar dataset
# map_1.save("ubicación_seleccionada.html")

# %% [markdown]
# ### Study of nearby location requirements

# %% [markdown]
# ####  2.1. Tech startups
# Near successful tech startups that have raised at least 1 Million dollars

# %% [markdown]
# #### Get all the businesses in San Francisco, founded after the year 2000, that have between 90 and 150 employees and that have raised at least 1 Million dollars. Excluding companies that have a value of None in the Offices / Latitude field.

# %%
filt1 = {'offices.city': {'$eq': "San Francisco"},
         'number_of_employees': { '$gt': 90,'$lt': 150 },
         'total_money_raised': {'$exists': True, '$ne': '$0' },
         'founded_year': { '$gte': 2000 },
         'offices.latitude' : { '$ne': None }
        }
project1 = {"_id":0,"name":1,"offices.city": 1,"offices.latitude":1,"offices.longitude": 1, 'total_money_raised': 1, 'founded_year': 1}
results = collection.find(filt1, project1)

df_1M = pd.DataFrame.from_records(results)
df_1M
# Out:
#                    name  founded_year total_money_raised  \
# 0                   hi5          2003               $52M
# 1             99designs          2008               $35M
# 2              LiveRail          2008               $12M
# 3  Wikimedia Foundation          2003               $74M
# 4                GitHub          2008              $100M
# 5             Cloudmark          2001             $38.5M
# 6                Minted          2007             $52.7M
# 7                Twilio          2007              $104M
# 8      Canopy Financial          2004             $89.5M
# 9           ZoomSystems          2002               $87M
#
#                                              offices
# 0  [{'city': 'San Francisco', 'latitude': 37.7886...
# 1  [{'city': 'San Francisco', 'latitude': 37.7955...
# 2  [{'city': 'San Francisco', 'latitude': 37.7871...
# 3  [{'city': 'San Francisco', 'latitude': 37.7678...
# 4  [{'city': 'San Francisco', 'latitude': 37.7751...
# 5  [{'city': 'San Francisco', 'latitude': 37.7795...
# 6  [{'city': 'San Francisco', 'latitude': 37.7974...
# 7  [{'city': 'San Francisco', 'latitude': 37.7898...
# 8  [{'city': 'San Francisco', 'latitude': 37.7913...
# 9  [{'city': 'San Francisco', 'latitude': 37.7816...

# %%
# Create new columns to indicate the coordinates and the tag.

def split_coordinates_lat(row):
    if 'offices' in row:
        for office in row['offices']:
            if office['city'] == 'San Francisco':
                return office['latitude']
    return None

def split_coordinates_lng(row):
    if 'offices' in row:
        for office in row['offices']:
            if office['city'] == 'San Francisco':
                return office['longitude']
    return None

def split_tag(row):
    if 'offices' in row:
        for office in row['offices']:
            if office['city'] == 'San Francisco':
                return 'Tech startups'
    return None

df_1M['lat'] = df_1M.apply(split_coordinates_lat, axis=1) 
df_1M['lng'] = df_1M.apply(split_coordinates_lng, axis=1) 
df_1M['tag'] = df_1M.apply(split_tag, axis=1)


# Delete all columns used for filter display
df_1M = df_1M.drop(['founded_year', 'total_money_raised', 'offices'], axis=1)
def_tech_startups = df_1M
def_tech_startups
# Out:
#                    name        lat         lng            tag
# 0                   hi5  37.788668 -122.400558  Tech startups
# 1             99designs  37.795531 -122.400598  Tech startups
# 2              LiveRail  37.787183 -122.397759  Tech startups
# 3  Wikimedia Foundation  37.767850 -122.392839  Tech startups
# 4                GitHub  37.775196 -122.419204  Tech startups
# 5             Cloudmark  37.779507 -122.390710  Tech startups
# 6                Minted  37.797435 -122.403175  Tech startups
# 7                Twilio  37.789850 -122.400683  Tech startups
# 8      Canopy Financial  37.791388 -122.392148  Tech startups
# 9           ZoomSystems  37.781689 -122.391061  Tech startups

# %%
# Create new column with distance between selected point and tag
def geo_distance(row):
    my_loc = (37.788668, -122.400558)
    row_loc = (row['lat'], row['lng'])
    return geodesic(my_loc, row_loc).miles

def_tech_startups['distance'] = def_tech_startups.apply(geo_distance, axis=1)
def_tech_startups = def_tech_startups.sort_values(['tag', 'distance'], ascending=[True, True])
def_tech_startups = def_tech_startups.reset_index(drop=True, inplace=False)
def_tech_startups
# Out:
#                    name        lat         lng            tag  distance
# 0                   hi5  37.788668 -122.400558  Tech startups  0.000000
# 1                Twilio  37.789850 -122.400683  Tech startups  0.081800
# 2              LiveRail  37.787183 -122.397759  Tech startups  0.184280
# 3             99designs  37.795531 -122.400598  Tech startups  0.473309
# 4      Canopy Financial  37.791388 -122.392148  Tech startups  0.497053
# 5                Minted  37.797435 -122.403175  Tech startups  0.621371
# 6           ZoomSystems  37.781689 -122.391061  Tech startups  0.708440
# 7             Cloudmark  37.779507 -122.390710  Tech startups  0.830513
# 8                GitHub  37.775196 -122.419204  Tech startups  1.380213
# 9  Wikimedia Foundation  37.767850 -122.392839  Tech startups  1.496649

# %%
min_distance = def_tech_startups["distance"].min()


print("The closest is to:", min_distance, "miles")
closest_tech_startups = def_tech_startups.loc[1]
closest_tech_startups
# Out:
# The closest is to: 0.0 miles
# name               Twilio
# lat               37.7898
# lng              -122.401
# tag         Tech startups
# distance        0.0817998
# Name: 1, dtype: object

# %% [markdown]
# ### 2. Connecting with Foursquare Api.

# %%
# Creating environment variables for identification in Foursquare
CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.getenv('CLIENT_SECRET')

# %%
# Variable definition for location coordinates
office_location = {'type': 'Point', 'coordinates': [latitude, longitude]}
print (office_location)
# Out:
# {'type': 'Point', 'coordinates': [37.788668, -122.400558]}

# %% [markdown]
# #### 2.2. Starbucks
# Executives like Starbucks A LOT

# %%
# Obtaining information from the Foursquare API, related to the Starbucks located within a radius of 500 m.
url_query = 'https://api.foursquare.com/v2/venues/explore'
starbucks = "556f676fbd6a75a99038d8ec"

# %%
parameters = {"client_id" : f"{CLIENT_ID}",
              "client_secret" : f"{CLIENT_SECRET}",
              "v": "20210419",
              "ll": f"{office_location.get('coordinates')[0]},{office_location.get('coordinates')[1]}",
              "query":"starbucks",
              "radius":500}

# %%
resp = requests.get(url= url_query, params = parameters).json()
print(resp.keys())

data = resp.get("response")
# print(data)
# Out:
# dict_keys(['meta', 'response'])

# %%
sites = []
group = data['groups'][0]
for item in group['items']:
    site_dict = {}
    site_dict['name'] = item['venue']['name']
    site_dict['lat'] = item['venue']['location']['lat']
    site_dict['lng'] = item['venue']['location']['lng']
    site_dict['tag'] = 'starbucks'
    
    sites.append(site_dict)
    
# print(sites)

# %%
# Insert into a dataframe
df_starbucks = pd.DataFrame(sites)
df_starbucks
# Out:
#          name        lat         lng        tag
# 0   Starbucks  37.789651 -122.396622  starbucks
# 1   Starbucks  37.791939 -122.397402  starbucks
# 2   Starbucks  37.790110 -122.395610  starbucks
# 3   Starbucks  37.791104 -122.400951  starbucks
# 4   Starbucks  37.788792 -122.400710  starbucks
# 5   Starbucks  37.787360 -122.403180  starbucks
# 6   Starbucks  37.789462 -122.397582  starbucks
# 7   Starbucks  37.785782 -122.396687  starbucks
# 8   Starbucks  37.790425 -122.405773  starbucks
# 9   Starbucks  37.787902 -122.401144  starbucks
# 10  Starbucks  37.789594 -122.402032  starbucks
# 11  Starbucks  37.791912 -122.398364  starbucks
# 12  Starbucks  37.790817 -122.404026  starbucks
# 13  Starbucks  37.793060 -122.399760  starbucks
# 14  Starbucks  37.792190 -122.403540  starbucks
# 15  Starbucks  37.784794 -122.399974  starbucks

# %%
# Create new column with distance between selected point and tag

def geo_distance(row):
    my_loc = (37.788668, -122.400558)
    row_loc = (row['lat'], row['lng'])
    return geodesic(my_loc, row_loc).miles

df_starbucks['distance'] = df_starbucks.apply(geo_distance, axis=1)
df_starbucks = df_starbucks.sort_values(['tag', 'distance'], ascending=[True, True])
df_starbucks = df_starbucks.reset_index(drop=True, inplace=False)
df_starbucks.head()
# Out:
#         name        lat         lng        tag  distance
# 0  Starbucks  37.788792 -122.400710  starbucks  0.011923
# 1  Starbucks  37.787902 -122.401144  starbucks  0.061794
# 2  Starbucks  37.789594 -122.402032  starbucks  0.102894
# 3  Starbucks  37.791104 -122.400951  starbucks  0.169411
# 4  Starbucks  37.787360 -122.403180  starbucks  0.169508

# %%
min_distance = df_starbucks["distance"].min()


print("The closest is to:", min_distance, "miles")
closest_starbucks = df_starbucks.loc[0]
closest_starbucks
# Out:
# The closest is to: 0.011923223971605636 miles
# name        Starbucks
# lat           37.7888
# lng          -122.401
# tag         starbucks
# distance    0.0119232
# Name: 0, dtype: object

# %% [markdown]
# #### 2.3 Airport.
# Account managers need to travel a lot

# %%
# Obtaining information from the Foursquare API, related to the Airport located within a radius of 230000 m.
url_query = 'https://api.foursquare.com/v2/venues/search'
airport = "4bf58dd8d48988d1ed931735"

# %%
parameters = {"client_id" : f"{CLIENT_ID}",
              "client_secret" : f"{CLIENT_SECRET}",
              "v": "20210419",
              "ll": f"{office_location.get('coordinates')[0]},{office_location.get('coordinates')[1]}",
              "categoryId": f"{airport}",
              "radius":23000}

# "query":f"{airport}"
# "query":"airport"

# %%
resp = requests.get(url= url_query, params = parameters).json()
print(resp.keys())
# print(json.dumps(resp, indent=4, sort_keys=True))
data = resp.get("response")
# print(data)
# Out:
# dict_keys(['meta', 'response'])

# %%
sites = []
# group = data['groups'][0]
for item in data['venues']:
    site_dict = {}
    site_dict['name'] = item['name']
    site_dict['lat'] = item['location']['lat']
    site_dict['lng'] = item['location']['lng']
    site_dict['tag'] = 'Airport'
    
    sites.append(site_dict)
    
# print(sites) 4bf58dd8d48988d1ed931735

# Insert into a dataframe
df = pd.DataFrame(sites)
df
# Out:
#                                                  name        lat         lng  \
# 0                                     Boarding Area D  37.617393 -122.381837
# 1                            Terminal 3 Baggage Claim  37.618107 -122.386107
# 2   San Francisco International Airport (SFO) (San...  37.616713 -122.387094
# 3   Oakland International Airport (OAK) (Oakland I...  37.711936 -122.213416
# 4                                The Centurion Lounge  37.617609 -122.387915
# 5                                         United Club  37.619309 -122.386880
# 6                                          Terminal 3  37.618217 -122.386354
# 7                                 Baggage Claim 1-2-3  37.617988 -122.387052
# 8                                          Terminal 2  37.616930 -122.383806
# 9                            United Airlines Check-in  37.617950 -122.386998
# 10                           TSA Pre Check Terminal 3  37.618002 -122.386450
# 11                  Southwest Airlines Ticket Counter  37.711828 -122.212031
# 12                                         Terminal 2  37.711223 -122.212129
# 13                             International Terminal  37.615931 -122.389390
# 14                             Harvey Milk Terminal 1  37.614639 -122.384884
# 15                           Signature Flight Support  37.628164 -122.384734
# 16                                         Terminal 1  37.711712 -122.214966
# 17                                    Boarding Area B  37.613034 -122.384836
# 18                            TSA Security Checkpoint  37.614437 -122.385330
# 19                                    Boarding Area C  37.615030 -122.382996
# 20                                    Boarding Area F  37.619942 -122.387674
# 21                            TSA Security Checkpoint  37.618157 -122.386539
# 22                                          SFO Apron  37.619195 -122.382116
# 23                           International Terminal A  37.613382 -122.389090
# 24                                      Baggage Claim  37.711294 -122.211540
# 25                                    Boarding Area E  37.618965 -122.384422
# 26             SFO AirTrain Station - Garage G & BART  37.615951 -122.392256
# 27                           International Terminal G  37.617775 -122.391225
# 28                             International Arrivals  37.615123 -122.390068
# 29           SFO AirTrain Station - Rental Car Center  37.628128 -122.401076
#
#         tag
# 0   Airport
# 1   Airport
# 2   Airport
# 3   Airport
# 4   Airport
# 5   Airport
# 6   Airport
# 7   Airport
# 8   Airport
# 9   Airport
# 10  Airport
# 11  Airport
# 12  Airport
# 13  Airport
# 14  Airport
# 15  Airport
# 16  Airport
# 17  Airport
# 18  Airport
# 19  Airport
# 20  Airport
# 21  Airport
# 22  Airport
# 23  Airport
# 24  Airport
# 25  Airport
# 26  Airport
# 27  Airport
# 28  Airport
# 29  Airport

# %%
# Function to keep the general rows
import re

def get_airport(row):

    pattern1 = r'.*\([A-Z]{3}\).*'
    sequence = row['name']

    if re.match(pattern1, sequence):
        return True
    
    return False

# Create column for filtering
df['Temporal'] = df.apply(get_airport, axis=1)
df
# Out:
#                                                  name        lat         lng  \
# 0                                     Boarding Area D  37.617393 -122.381837
# 1                            Terminal 3 Baggage Claim  37.618107 -122.386107
# 2   San Francisco International Airport (SFO) (San...  37.616713 -122.387094
# 3   Oakland International Airport (OAK) (Oakland I...  37.711936 -122.213416
# 4                                The Centurion Lounge  37.617609 -122.387915
# 5                                         United Club  37.619309 -122.386880
# 6                                          Terminal 3  37.618217 -122.386354
# 7                                 Baggage Claim 1-2-3  37.617988 -122.387052
# 8                                          Terminal 2  37.616930 -122.383806
# 9                            United Airlines Check-in  37.617950 -122.386998
# 10                           TSA Pre Check Terminal 3  37.618002 -122.386450
# 11                  Southwest Airlines Ticket Counter  37.711828 -122.212031
# 12                                         Terminal 2  37.711223 -122.212129
# 13                             International Terminal  37.615931 -122.389390
# 14                             Harvey Milk Terminal 1  37.614639 -122.384884
# 15                           Signature Flight Support  37.628164 -122.384734
# 16                                         Terminal 1  37.711712 -122.214966
# 17                                    Boarding Area B  37.613034 -122.384836
# 18                            TSA Security Checkpoint  37.614437 -122.385330
# 19                                    Boarding Area C  37.615030 -122.382996
# 20                                    Boarding Area F  37.619942 -122.387674
# 21                            TSA Security Checkpoint  37.618157 -122.386539
# 22                                          SFO Apron  37.619195 -122.382116
# 23                           International Terminal A  37.613382 -122.389090
# 24                                      Baggage Claim  37.711294 -122.211540
# 25                                    Boarding Area E  37.618965 -122.384422
# 26             SFO AirTrain Station - Garage G & BART  37.615951 -122.392256
# 27                           International Terminal G  37.617775 -122.391225
# 28                             International Arrivals  37.615123 -122.390068
# 29           SFO AirTrain Station - Rental Car Center  37.628128 -122.401076
#
#         tag  Temporal
# 0   Airport     False
# 1   Airport     False
# 2   Airport      True
# 3   Airport      True
# 4   Airport     False
# 5   Airport     False
# 6   Airport     False
# 7   Airport     False
# 8   Airport     False
# 9   Airport     False
# 10  Airport     False
# 11  Airport     False
# 12  Airport     False
# 13  Airport     False
# 14  Airport     False
# 15  Airport     False
# 16  Airport     False
# 17  Airport     False
# 18  Airport     False
# 19  Airport     False
# 20  Airport     False
# 21  Airport     False
# 22  Airport     False
# 23  Airport     False
# 24  Airport     False
# 25  Airport     False
# 26  Airport     False
# 27  Airport     False
# 28  Airport     False
# 29  Airport     False

# %%
# Delete the rows whose value is False in the column 'Temporary'
df_airport = df.copy()
df_airport.drop(df_airport[df_airport['Temporal'] == False].index, inplace = True)
df_airport
# Out:
#                                                 name        lat         lng  \
# 2  San Francisco International Airport (SFO) (San...  37.616713 -122.387094
# 3  Oakland International Airport (OAK) (Oakland I...  37.711936 -122.213416
#
#        tag  Temporal
# 2  Airport      True
# 3  Airport      True

# %%
# Delete all columns used for filter display 'Temporal'
df_airport = df_airport.drop(['Temporal'], axis=1)
df_airport = df_airport.reset_index(drop=True, inplace=False)
df_airport
# Out:
#                                                 name        lat         lng  \
# 0  San Francisco International Airport (SFO) (San...  37.616713 -122.387094
# 1  Oakland International Airport (OAK) (Oakland I...  37.711936 -122.213416
#
#        tag
# 0  Airport
# 1  Airport

# %% [markdown]
# #### 2.4 Nightlife Spot
# Everyone in the company is between 25 and 40

# %%
# Obtaining information from the Foursquare API, related to the Night clubs located within a radius of 500 m.
url_query = 'https://api.foursquare.com/v2/venues/search'
nightlife_spot = "4d4b7105d754a06376d81259"

# %%
parameters = {"client_id" : f"{CLIENT_ID}",
              "client_secret" : f"{CLIENT_SECRET}",
              "v": "20210419",
              "ll": f"{office_location.get('coordinates')[0]},{office_location.get('coordinates')[1]}",
              "categoryId": f"{nightlife_spot}",
              "radius":500}

# %%
resp = requests.get(url= url_query, params = parameters).json()
print(resp.keys())

data = resp.get("response")
# print(data)
# Out:
# dict_keys(['meta', 'response'])

# %%
sites = []
for item in data['venues']:
    site_dict = {}
    site_dict['name'] = item['name']
    site_dict['lat'] = item['location']['lat']
    site_dict['lng'] = item['location']['lng']
    site_dict['tag'] = 'Nightlife Spot'
    
    sites.append(site_dict)
    
# print(sites)
df_nightlife_spot = pd.DataFrame(sites)
df_nightlife_spot
# Out:
#                              name        lat         lng             tag
# 0                  Sutter Station  37.789960 -122.400915  Nightlife Spot
# 1                          Novela  37.786927 -122.401246  Nightlife Spot
# 2       Galleria Park Hotel Lobby  37.789696 -122.403446  Nightlife Spot
# 3                  Bluestone Lane  37.787813 -122.402913  Nightlife Spot
# 4        Kona’s Street Market Bar  37.787040 -122.403241  Nightlife Spot
# 5            Kona's Street Market  37.787064 -122.403270  Nightlife Spot
# 6                    Sam’s Tavern  37.790932 -122.403559  Nightlife Spot
# 7   ALX by Alexander's Steakhouse  37.784679 -122.398408  Nightlife Spot
# 8                   Natoma Cabana  37.787600 -122.398502  Nightlife Spot
# 9               The Pink Elephant  37.786813 -122.400456  Nightlife Spot
# 10               Temple Nightclub  37.787898 -122.397227  Nightlife Spot
# 11        W SF Events (3rd Floor)  37.785483 -122.400088  Nightlife Spot
# 12                 Atlas Tap Room  37.787880 -122.400027  Nightlife Spot
# 13                   The Treasury  37.791229 -122.400821  Nightlife Spot
# 14                       The View  37.785349 -122.404362  Nightlife Spot
# 15              Elements By One65  37.786449 -122.406938  Nightlife Spot
# 16                      Gold Club  37.785944 -122.399693  Nightlife Spot
# 17    ThirstyBear Brewing Company  37.785488 -122.399614  Nightlife Spot
# 18                           MaSo  37.786520 -122.403100  Nightlife Spot
# 19              Café de la Presse  37.790493 -122.405492  Nightlife Spot
# 20      B55 Craft House & Kitchen  37.784979 -122.404248  Nightlife Spot
# 21                       The Lark  37.787041 -122.402996  Nightlife Spot
# 22           Whispers Bar & Grill  37.785977 -122.396779  Nightlife Spot
# 23                 Wayfare Tavern  37.793903 -122.402272  Nightlife Spot
# 24                       Perbacco  37.793288 -122.399134  Nightlife Spot
# 25                   The Fly Trap  37.785423 -122.396929  Nightlife Spot
# 26      The Occidental Cigar Club  37.791796 -122.403780  Nightlife Spot
# 27                    Toy Soldier  37.791459 -122.403833  Nightlife Spot
# 28             B Restaurant & Bar  37.784652 -122.401668  Nightlife Spot
# 29                     Pagan Idol  37.790726 -122.403643  Nightlife Spot

# %%
# Create new column with distance between selected point and tag

def geo_distance(row):
    my_loc = (37.788668, -122.400558)
    row_loc = (row['lat'], row['lng'])
    return geodesic(my_loc, row_loc).miles

df_nightlife_spot['distance'] = df_nightlife_spot.apply(geo_distance, axis=1)
df_nightlife_spot = df_nightlife_spot.sort_values(['tag', 'distance'], ascending=[True, True])
df_nightlife_spot = df_nightlife_spot.reset_index(drop=True, inplace=False)
df_nightlife_spot.head()
# Out:
#                 name        lat         lng             tag  distance
# 0     Atlas Tap Room  37.787880 -122.400027  Nightlife Spot  0.061661
# 1     Sutter Station  37.789960 -122.400915  Nightlife Spot  0.091218
# 2             Novela  37.786927 -122.401246  Nightlife Spot  0.125852
# 3  The Pink Elephant  37.786813 -122.400456  Nightlife Spot  0.128047
# 4      Natoma Cabana  37.787600 -122.398502  Nightlife Spot  0.134470

# %%
min_distance = df_nightlife_spot["distance"].min()


print("The closest is to:", min_distance, "miles")
closest_nightlife_spot = df_nightlife_spot.loc[0]
closest_nightlife_spot
# Out:
# The closest is to: 0.06166116188982341 miles
# name        Atlas Tap Room
# lat                37.7879
# lng                 -122.4
# tag         Nightlife Spot
# distance         0.0616612
# Name: 0, dtype: object

# %% [markdown]
# #### 2.5 Vegan restaurants.
# The CEO is vegan.

# %%
# Obtaining information from the Foursquare API, related to the Vegan restaurants located within a radius of 500 m.
url_query = 'https://api.foursquare.com/v2/venues/explore'
vegan_restaurants = "4bf58dd8d48988d1d3941735"

# %%
parameters = {"client_id" : f"{CLIENT_ID}",
              "client_secret" : f"{CLIENT_SECRET}",
              "v": "20210419",
              "ll": f"{office_location.get('coordinates')[0]},{office_location.get('coordinates')[1]}",
              "categoryId": f"{vegan_restaurants}",
              "radius":500}

# %%
resp = requests.get(url= url_query, params = parameters).json()
print(resp.keys())

data = resp.get("response")
# print(data)
# Out:
# dict_keys(['meta', 'response'])

# %%
sites = []
group = data['groups'][0]
for item in group['items']:
    site_dict = {}
    site_dict['name'] = item['venue']['name']
    site_dict['lat'] = item['venue']['location']['lat']
    site_dict['lng'] = item['venue']['location']['lng']
    site_dict['tag'] = 'Vegan restaurants'
    
    sites.append(site_dict)
    
# print(sites)
df_vegan = pd.DataFrame(sites)
df_vegan
# Out:
#                        name        lat         lng                tag
# 0                sweetgreen  37.787262 -122.398635  Vegan restaurants
# 1                      Mixt  37.788844 -122.399149  Vegan restaurants
# 2                      Mixt  37.785751 -122.404124  Vegan restaurants
# 3    The Plant Cafe Organic  37.792525 -122.398465  Vegan restaurants
# 4                  Elixiria  37.792053 -122.396844  Vegan restaurants
# 5                      Mixt  37.791589 -122.400787  Vegan restaurants
# 6              Sunrise Deli  37.788611 -122.400532  Vegan restaurants
# 7    The Plant Cafe Organic  37.791888 -122.402499  Vegan restaurants
# 8                     Amber  37.785967 -122.404567  Vegan restaurants
# 9                      Fang  37.785667 -122.399703  Vegan restaurants
# 10          WeTheTrillions.  37.790158 -122.402439  Vegan restaurants
# 11                 Delarosa  37.786230 -122.404235  Vegan restaurants
# 12            Dosa Brothers  37.789021 -122.401848  Vegan restaurants
# 13  Ginto Izakaya Japonaise  37.788313 -122.402916  Vegan restaurants

# %%
# Create new column with distance between selected point and tag

def geo_distance(row):
    my_loc = (37.788668, -122.400558)
    row_loc = (row['lat'], row['lng'])
    return geodesic(my_loc, row_loc).miles

df_vegan['distance'] = df_vegan.apply(geo_distance, axis=1)
df_vegan = df_vegan.sort_values(['tag', 'distance'], ascending=[True, True])
df_vegan = df_vegan.reset_index(drop=True, inplace=False)
df_vegan.head()
# Out:
#                       name        lat         lng                tag  distance
# 0             Sunrise Deli  37.788611 -122.400532  Vegan restaurants  0.004189
# 1            Dosa Brothers  37.789021 -122.401848  Vegan restaurants  0.074679
# 2                     Mixt  37.788844 -122.399149  Vegan restaurants  0.078068
# 3  Ginto Izakaya Japonaise  37.788313 -122.402916  Vegan restaurants  0.131362
# 4               sweetgreen  37.787262 -122.398635  Vegan restaurants  0.143104

# %%
min_distance = df_vegan["distance"].min()


print("The closest is to:", min_distance, "miles")
closest_vegan = df_vegan.loc[0]
closest_vegan
# Out:
# The closest is to: 0.004189114153864005 miles
# name             Sunrise Deli
# lat                   37.7886
# lng                  -122.401
# tag         Vegan restaurants
# distance           0.00418911
# Name: 0, dtype: object

# %% [markdown]
# #### 2.6 Daycare.
# 30% of the company staff have at least 1 child.

# %%
# Obtaining information from the Foursquare API, related to the Daycare located within a radius of 500 m.
url_query = 'https://api.foursquare.com/v2/venues/explore'
daycare = "5744ccdfe4b0c0459246b4c7"

# %%
parameters = {"client_id" : f"{CLIENT_ID}",
              "client_secret" : f"{CLIENT_SECRET}",
              "v": "20210419",
              "ll": f"{office_location.get('coordinates')[0]},{office_location.get('coordinates')[1]}",
              "categoryId": f"{daycare}",
              "radius":500}

# %%
resp = requests.get(url= url_query, params = parameters).json()
print(resp.keys())

data = resp.get("response")
# print(data)
# Out:
# dict_keys(['meta', 'response'])

# %%
sites = []
group = data['groups'][0]
for item in group['items']:
    site_dict = {}
    site_dict['name'] = item['venue']['name']
    site_dict['lat'] = item['venue']['location']['lat']
    site_dict['lng'] = item['venue']['location']['lng']
    site_dict['tag'] = 'Daycare'
    
    sites.append(site_dict)
    
# print(sites)
df_daycare = pd.DataFrame(sites)
df_daycare
# Out:
#                                    name        lat         lng      tag
# 0  Kids by the Bay - Financial District  37.785471 -122.398037  Daycare
# 1                       Bright Horizons  37.792097 -122.403744  Daycare
# 2      Marin Day Schools Fremont Street  37.789582 -122.395118  Daycare

# %%
# Create new column with distance between selected point and tag

def geo_distance(row):
    my_loc = (37.788668, -122.400558)
    row_loc = (row['lat'], row['lng'])
    return geodesic(my_loc, row_loc).miles

df_daycare['distance'] = df_daycare.apply(geo_distance, axis=1)
df_daycare = df_daycare.sort_values(['tag', 'distance'], ascending=[True, True])
df_daycare = df_daycare.reset_index(drop=True, inplace=False)
df_daycare.head()
# Out:
#                                    name        lat         lng      tag  \
# 0  Kids by the Bay - Financial District  37.785471 -122.398037  Daycare
# 1                       Bright Horizons  37.792097 -122.403744  Daycare
# 2      Marin Day Schools Fremont Street  37.789582 -122.395118  Daycare
#
#    distance
# 0  0.260106
# 1  0.293826
# 2  0.304370

# %%
min_distance = df_daycare["distance"].min()


print("The closest is to:", min_distance, "miles")
closest_daycare = df_daycare.loc[0]
closest_daycare
# Out:
# The closest is to: 0.2601060315122544 miles
# name        Kids by the Bay - Financial District
# lat                                      37.7855
# lng                                     -122.398
# tag                                      Daycare
# distance                                0.260106
# Name: 0, dtype: object

# %% [markdown]
# ### 3. General dataset with all points located

# %%
# Concatenation of all datasets

df_all = pd.concat([df_my_company, def_tech_startups, df_starbucks, df_airport, df_nightlife_spot, df_vegan, df_daycare])
df_all = df_all.reset_index(drop=True, inplace=False)

df_all
# Out:
#                                     name        lat         lng  \
# 0                              MyCompany  37.788668 -122.400558
# 1                                    hi5  37.788668 -122.400558
# 2                              99designs  37.795531 -122.400598
# 3                               LiveRail  37.787183 -122.397759
# 4                   Wikimedia Foundation  37.767850 -122.392839
# ..                                   ...        ...         ...
# 71                         Dosa Brothers  37.789021 -122.401848
# 72               Ginto Izakaya Japonaise  37.788313 -122.402916
# 73  Kids by the Bay - Financial District  37.785471 -122.398037
# 74                       Bright Horizons  37.792097 -122.403744
# 75      Marin Day Schools Fremont Street  37.789582 -122.395118
#
#                   tag
# 0         my_location
# 1       Tech startups
# 2       Tech startups
# 3       Tech startups
# 4       Tech startups
# ..                ...
# 71  Vegan restaurants
# 72  Vegan restaurants
# 73            Daycare
# 74            Daycare
# 75            Daycare
#
# [76 rows x 4 columns]

# %%
df_all['tag'].value_counts()
# Out:
# Nightlife Spot       30
# starbucks            16
# Vegan restaurants    14
# Tech startups        10
# Daycare               3
# Airport               2
# my_location           1
# Name: tag, dtype: int64

# %%
# Create new column with distance between selected point and tag

from geopy.distance import geodesic
newport_ri = (41.49008, -71.312796)
cleveland_oh = (41.499498, -81.695391)
print(geodesic(newport_ri, cleveland_oh).miles)

def geo_distance(row):
    my_loc = (37.788668, -122.400558)
    row_loc = (row['lat'], row['lng'])
    return geodesic(my_loc, row_loc).miles

df_all['distance'] = df_all.apply(geo_distance, axis=1)
df_all = df_all.sort_values(['tag', 'distance'], ascending=[True, True])
df_all = df_all.reset_index(drop=True, inplace=False)
df_all
# Out:
# 538.3904453677205
#                                                  name        lat         lng  \
# 0   Oakland International Airport (OAK) (Oakland I...  37.711936 -122.213416
# 1   San Francisco International Airport (SFO) (San...  37.616713 -122.387094
# 2                Kids by the Bay - Financial District  37.785471 -122.398037
# 3                                     Bright Horizons  37.792097 -122.403744
# 4                    Marin Day Schools Fremont Street  37.789582 -122.395118
# ..                                                ...        ...         ...
# 71                                          Starbucks  37.790110 -122.395610
# 72                                          Starbucks  37.785782 -122.396687
# 73                                          Starbucks  37.792190 -122.403540
# 74                                          Starbucks  37.793060 -122.399760
# 75                                          Starbucks  37.790425 -122.405773
#
#           tag   distance
# 0     Airport  11.533783
# 1     Airport  11.882063
# 2     Daycare   0.260106
# 3     Daycare   0.293826
# 4     Daycare   0.304370
# ..        ...        ...
# 71  starbucks   0.288499
# 72  starbucks   0.290696
# 73  starbucks   0.292642
# 74  starbucks   0.306038
# 75  starbucks   0.310113
#
# [76 rows x 5 columns]

# %%
# Exportar dataset 1
# df_all.to_csv(r"C:\Users\sussy\CODE\Week_4\w4_geospatia_project\output\all_points_located.csv", index = False)

# %% [markdown]
# ### 4. Visualization on  map

# %% [markdown]
# #### Heat map

# %%
heat_map = folium.Map (location = [latitude, longitude], zoom_start = 15)

# %%
tag_tech_startups = df_all[df_all.tag == "Tech startups"]
tag_tech_group = folium.FeatureGroup(name = "Tech startups")
HeatMap(data = tag_tech_startups[["lat","lng"]], radius = 15).add_to(tag_tech_group)
tag_tech_group.add_to(heat_map)

tag_starbucks = df_all[df_all.tag == "starbucks"]
starbucks_group = folium.FeatureGroup(name = "Starbucks")
HeatMap(data = tag_starbucks[["lat","lng"]], radius = 15).add_to(starbucks_group)
starbucks_group.add_to(heat_map)

tag_airport = df_all[df_all.tag == "Airport"]
airport_group = folium.FeatureGroup(name = "Airport")
HeatMap(data = tag_airport[["lat","lng"]], radius = 15).add_to(airport_group)
airport_group.add_to(heat_map)

tag_nightlife_spot = df_all[df_all.tag == "Nightlife Spot"]
nightlife_spot_group = folium.FeatureGroup(name = "Nightlife Spot")
HeatMap(data = tag_nightlife_spot[["lat","lng"]], radius = 15).add_to(nightlife_spot_group)
nightlife_spot_group.add_to(heat_map)

tag_vegan_restaurants = df_all[df_all.tag == "Vegan restaurants"]
vegan_restaurants_group = folium.FeatureGroup(name = "Vegan restaurants")
HeatMap(data = tag_vegan_restaurants[["lat","lng"]], radius = 15).add_to(vegan_restaurants_group)
vegan_restaurants_group.add_to(heat_map)

tag_daycare = df_all[df_all.tag == "Daycare"]
daycare_group = folium.FeatureGroup(name = "Daycare")
HeatMap(data = tag_daycare[["lat","lng"]], radius = 15).add_to(daycare_group)
daycare_group.add_to(heat_map)

# %%
icon = Icon(color = "white",
            prefix = "fa",
            icon = "building-o",
            icon_color = "green")
loc = {"location":[latitude, longitude],
       "tooltip": "My location"}

marker_office = Marker(**loc, icon = icono)
marker_office.add_to(heat_map)

# %%
folium.LayerControl(collapsed=False).add_to(heat_map)

# %%
heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6bc7e7842d6c4315acbb5d25ee30e3c6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6bc7e7842d6c4315acbb5d25ee30e3c6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6bc7e7842d6c4315acbb5d25ee30e3c6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6bc7e7842d6c4315acbb5d25ee30e3c6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %%
# Exportar dataset
# heat_map.save("all_heat_map.html")

# %% [markdown]
# #### Markers map

# %%
map_all = folium.Map(location = [latitude, longitude], zoom_start = 15)

for i,row in df_all.iterrows():
    name = {"location" : [row["lat"], row["lng"]],
            "tooltip" : row["name"]}
    
    if row["tag"] == "starbucks":
        icon = Icon(color = "green",
                    prefix = "fa",
                    icon = "coffee",
                    icon_color = "white")  
        
    elif row["tag"] == 'Tech startups':
        icon = Icon(color = "blue",
                    prefix = "fa",
                    icon = "line-chart",
                    icon_color = "beige")      
        
    elif row["tag"] == 'my_location':
        icon = Icon(color = "red",
                    prefix = "fa",
                    icon = "hand-spock-o",
                    icon_color = "beige")
        
    elif row["tag"] == 'Airport':
        icon = Icon(color = "red",
                    prefix = "fa",
                    icon = "plane",
                    icon_color = "beige")
        
    elif row["tag"] == 'Nightlife Spot':
        icon = Icon(color = "darkpurple",
                    prefix = "fa",
                    icon = "glass",
                    icon_color = "beige")
        
    elif row["tag"] == 'Vegan restaurants':
        icon = Icon(color = "purple",
                    prefix = "fa",
                    icon = "lemon-o",
                    icon_color = "beige")
        
    elif row["tag"] == 'Daycare':
        icon = Icon(color = "pink",
                    prefix = "fa",
                    icon = "child",
                    icon_color = "beige")
        
        
    else:
        icon = Icon(color = "orange",
                    prefix = "fa",
                    icon = "building-o",
                    icon_color = "black")
        
    Marker(**name, icon = icon).add_to(map_all)
    
map_all
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b9c4d55b1d82489b8b47c65cdfecda5d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b9c4d55b1d82489b8b47c65cdfecda5d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b9c4d55b1d82489b8b47c65cdfecda5d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b9c4d55b1d82489b8b47c65cdfecda5d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.788668%2C%20-122.400558%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Exportar dataset
# map_all.save("all_markers_map.html")
