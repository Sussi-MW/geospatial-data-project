# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
# uploaded = files.upload()

# %% [markdown]
# Import the necessary modules for the project

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 5. Analysis of data

# %%
data = pd.read_csv("drive/MyDrive/Colab Notebooks/csv_data/all_points_located.csv",encoding = "ISO-8859-1")

# %%
data.head()
# Out:
#                                                 name  ...   distance
# 0  Oakland International Airport (OAK) (Oakland I...  ...  11.533783
# 1  San Francisco International Airport (SFO) (San...  ...  11.882063
# 2               Kids by the Bay - Financial District  ...   0.260106
# 3                                    Bright Horizons  ...   0.293826
# 4                   Marin Day Schools Fremont Street  ...   0.304370
#
# [5 rows x 5 columns]

# %%
plt.figure(figsize=(15, 10))
g = sns.countplot(x=data['tag'], palette="Set2")

# %% [markdown]
# Within a radius of 500m from the selected location, we have located the following sites:
#
# - 16 Starbucks.
# * Nearestt Starbucks: 37.788792	-122.400710	-	dist 0.011923 miles
#
#
# - 30 Nightlife Spot
# * Nearestt Nightlife Spot: Atlas Tap Room	37.787880	-122.400027 - dist 0.061661 miles
#
#
# - 14 Vegan restaurants
# * Nearestt Vegan restaurants: Sunrise Deli	37.788611	-122.400532	- dist 0.004189 miles
#
#
# - 3 Daycare
# * Nearestt Daycare: Kids by the Bay - Financial District	37.785471	-122.398037	- dist 0.260106 miles
#
# The city has two airports.
#
# Also, very close to the office location are 10 successful tech startups.
# * Nearestt tech startups:  Twilio	37.789850	-122.400683	-	0.081800 miles
